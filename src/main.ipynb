# %% [markdown]
# <br>
# <img src="https://web.unipv.it/wp-content/uploads/2021/04/MAIN_LOGO_suduerighe_1000x1000_Granata-su-bianco-300x118.png" width="250" align="right">
# <br><br><br>
#
# # Ornamental value estimation:
# ### No-SQL database for Interdisciplinary study on autoctone botanic species
#
# <br>
#
# #### Course:
# Digital Content Retrieval (<a href="http://csu.unipv.it/didattica/">CSU</a>)
#
# #### Authors:
# Aiman Al Masoud, Amato Francesco, Andrei Blindu, Mattia Bottini, Davide Lotito, Francesco Marinelli, Daniele Murer, Riccardo Petri, Fabio Tagliani
#
# #### Academic year:
# 2021-2022
#
# ![Licence](https://img.shields.io/github/license/Ileriayo/markdown-badges?style=for-the-badge)

# %% [markdown]
# ## Introduction
# Add some content here
# <br><br>

# %% [markdown]
# ## Import

# %%
## Import libraries
import pandas as pd
import json
import pymongo

from utilities import *

# Import dataset:
raw = "http://csu.unipv.it/wp-content/uploads/2022/01/Database_ornamentali_grezzo.xls"

# %% [markdown]
# ### Converting the .xls to dataframe

# %%
# Get dataframes starting from existing paths
raw_df = pd.read_excel(raw)

# %%
raw_df
# Out:
#                          TAXON 4030 2330+6210(acid) 6210(calc)  \
# 0          Aegilops_geniculata  NaN             NaN          X
# 1         Achillea_millefolium    X               X        NaN
# 2           Achillea_tomentosa  NaN               X          X
# 3          Agrostis_capillaris    X               X        NaN
# 4            Aira_caryophyllea    X               X          X
# ..                         ...  ...             ...        ...
# 217  Vincetoxicum_hirundinaria    X             NaN        NaN
# 218             Viola_arvensis  NaN               X          X
# 219               Viola_canina    X             NaN        NaN
# 220             Vulpia_ciliata  NaN               X          X
# 221              Vulpia_myurus    X               X          X
#
#      FORMA BIOLOGICA               DIMENSIONE FIORE  VISTOSITA'  \
# 0                1.0                            NaN           0
# 1                2.0             2,5 - 3 x 4- 5 cm            1
# ...

# %% [markdown]
# ## Obtain ornamental score from plants

# %% [markdown]
# ### Test: compute the ornamental value for a single row/record/plant:

# %%
"""
Remember that "get_score_sum" & "get_ornamental_index_value" functions are contained into the 
other .ipynb file, named as "utilities"
"""

print('SCORE SUM: ' + str(get_score_sum(raw_df.loc[0])))
print('ORNAMENTAL VALUE: ' + str(get_ornamental_index_value(raw_df.loc[0])))
# Out:
# SCORE SUM: 4.0
# ORNAMENTAL VALUE: 1

# %% [markdown]
# ### Goal: do it for all of the plants:

# %%
""" SCORE SUM FOR EACH PLANT """
raw_df.apply(get_score_sum, axis=1)
# Out:
# 0       4.0
# 1      11.0
# 2      10.0
# 3       7.0
# 4       3.0
#        ...
# 217     7.0
# 218    10.0
# 219    10.0
# 220     6.0
# 221     6.0
# Length: 222, dtype: float64

# %%
""" ORNAMENTAL VALUE FOR EACH PLANT """
raw_df.apply(get_ornamental_index_value, axis=1)
# Out:
# 0      1.0
# 1      3.0
# 2      3.0
# 3      2.0
# 4      1.0
#       ...
# 217    2.0
# 218    3.0
# 219    3.0
# 220    2.0
# 221    2.0
# Length: 222, dtype: float64

# %% [markdown]
# ## Generate the json array

# %% [markdown]
# We want to add our figures of merit to the single plant and then create a single json file containing all this information.

# %%
# Add the sum score and ornamental value to each plant
sum_of_scores = list(raw_df.apply(get_score_sum, axis=1))
all_ornamental_values = list(raw_df.apply(get_ornamental_index_value, axis=1))

raw_df["SOMMA DEI PUNTEGGI"] = sum_of_scores
raw_df["INDICE DI ORNAMENTALITA'"] = all_ornamental_values

# %%
""" SHOW THE NEW DATAFRAME WITH FIGURES OF MERIT """
raw_df
# Out:
#                          TAXON 4030 2330+6210(acid) 6210(calc)  \
# 0          Aegilops_geniculata  NaN             NaN          X
# 1         Achillea_millefolium    X               X        NaN
# 2           Achillea_tomentosa  NaN               X          X
# 3          Agrostis_capillaris    X               X        NaN
# 4            Aira_caryophyllea    X               X          X
# ..                         ...  ...             ...        ...
# 217  Vincetoxicum_hirundinaria    X             NaN        NaN
# 218             Viola_arvensis  NaN               X          X
# 219               Viola_canina    X             NaN        NaN
# 220             Vulpia_ciliata  NaN               X          X
# 221              Vulpia_myurus    X               X          X
#
#      FORMA BIOLOGICA               DIMENSIONE FIORE  VISTOSITA'  \
# 0                1.0                            NaN           0
# 1                2.0             2,5 - 3 x 4- 5 cm            1
# ...

# %%
"""
Remember that "dataframe_to_json_array" function is contained into the other .ipynb file, named
as "utilities"
"""

# get the json array as a string
json_array = dataframe_to_json_array(raw_df)
# convert to a python object and check json syntax
json_file = json.loads(json_array)

# %% [markdown]
# ## Store the obtained json

# %% [markdown]
# ### Locally

# %%
"""
Remember that "store_locally" function is contained into the other .ipynb file, named
as "utilities"
The file will be saved in the previous folder where this ".ipynb" file is located
"""

store_locally(json_file)

# %% [markdown]
# ### Into our mongodb istance

# %%
"""
Remember that "store_into_mongodb_istance" function is contained into the other .ipynb file, named
as "utilities"
"""

store_into_mongodb_istance(json_file)

# %% [markdown]
# ## Test: load a single document (plant) from the Mongodb instance:

# %%
client = pymongo.MongoClient(get_connection_string())

# %%
client.OVE.data.find()[10]
# Out:
# {'_id': ObjectId('61e19fc1a376686dd6cd9dba'),
#  'TAXON': 'Plantago_lanceolata',
#  '4030': True,
#  '2330+6210(acid)': True,
#  '6210(calc)': True,
#  'FORMA BIOLOGICA': 2.0,
#  'DIMENSIONE FIORE': 'spiga di 1-5 cm ',
#  "VISTOSITA'": 0,
#  'PERIODO FIORITURA': 'Maggio-luglio',
#  'DURATA': 'nan',
#  'PRESENZA MERCATO': 'Plantago major variegata ',
#  'MERCATO': 'nan',
#  'AROMATICA': 0,
#  'IMPOLLINAZIONE': 1,
#  'ALLERGENICITA’': 0,
#  'TOSSICITA’': 1,
#  'SOMMA DEI PUNTEGGI': 7.0,
#  "INDICE DI ORNAMENTALITA'": 2.0}

# %% [markdown]
# ### TODO: remove repeated records

# %%
#Tot num plants 
len(pd.read_json("../ornamental_db.json"))
# Out:
# 222

# %%
# TODO: remove repeated records! (Tot num plants = 222)
client.OVE.data.count_documents({})
# Out:
# 1554
