# %% [markdown]
# <img src="https://web.unipv.it/wp-content/uploads/2021/04/MAIN_LOGO_suduerighe_1000x1000_Granata-su-bianco-300x118.png" style="float: right; width: 20em; margin-left: 100px;">
#
# # Ornamental Value Estimation
#
# ## No-SQL Database for an Interdisciplinary Study on Autoctone Botanic Species
#
# ### Course
# Digital Content Retrieval ([CSU](http://csu.unipv.it/didattica/))
#
# ### Team Members
# Aiman Al Masoud, Amato Francesco, Andrei Blindu, Mattia Bottini, Davide Lotito, Francesco Marinelli, Daniele Murer, Riccardo Petri, Fabio Tagliani
#
# ### Academic year
# 2021/22
#
# ![License](https://img.shields.io/github/license/Ileriayo/markdown-badges?style=for-the-badge)

# %% [markdown]
# ## Introduction
#
# The raw dataset, in `.xls` format, was obtained from the CSU website:
#
# [http://csu.unipv.it/wp-content/uploads/2022/01/Database_ornamentali_grezzo.xls](http://csu.unipv.it/wp-content/uploads/2022/01/Database_ornamentali_grezzo.xls)
#
# ### Data manipulation steps
#
# 1.  The raw data was loaded into a pandas DataFrame.
#
# 2.  The data was cleaned up, and the values for the following data processing steps were made consistent with each other.
#
# 3.  Then the data was processed to obtain the "ornamental value" metric, using 8 relevant parameters to calculate it. The function that computes this metric, toghether with the data, is based on the work by F. Colombini available at [http://csu.unipv.it/wp-content/uploads/2022/01/Tesi-Colombini.pdf](http://csu.unipv.it/wp-content/uploads/2022/01/Tesi-Colombini.pdf).
#
#     The **ornamental value** is a figure of merit that can be used in order to decide if a specific species can be planted in a given area. The higher the ornamental value, the better the final result should be.
#
# 4.  Then the data was converted into a list of `json` objects and stored into a remote MongoDB instance.
#
# MongoDB was found to be ideal for this kind of application, since different plant species have different characteristics, and MongoDB allows for a loose structuring of the documents as opposed to relational databases.
#
# We used the free online MongoDB hosting service [Atlas](https://www.mongodb.com/atlas/database) to store the data, so that we could all collaborate on the project. We used the `pymongo` Python API to interact with the remote instance of the database.
#
# If you wish to download the dataset in `json` format use this download link: <a href="https://drive.google.com/uc?export=download&id=1qbFqC_eSVcBgorBP0HvW2fprnrDihGQP" title="Download the dataset" target="_blank">dataset</a>.

# %% [markdown]
# ## Data Import

# %%
# Import the libraries
import pandas as pd
import json
import pymongo

from utilities import *

# Import the dataset
raw = 'http://csu.unipv.it/wp-content/uploads/2022/01/Database_ornamentali_grezzo.xls'

# %% [markdown]
# ### Converting the `.xls` to a DataFrame

# %%
# Create the DataFrame starting from the given path
raw_df = pd.read_excel(raw)

# %%
raw_df
# Out:
#                          TAXON 4030 2330+6210(acid) 6210(calc)  \
# 0          Aegilops_geniculata  NaN             NaN          X
# 1         Achillea_millefolium    X               X        NaN
# 2           Achillea_tomentosa  NaN               X          X
# 3          Agrostis_capillaris    X               X        NaN
# 4            Aira_caryophyllea    X               X          X
# ..                         ...  ...             ...        ...
# 217  Vincetoxicum_hirundinaria    X             NaN        NaN
# 218             Viola_arvensis  NaN               X          X
# 219               Viola_canina    X             NaN        NaN
# 220             Vulpia_ciliata  NaN               X          X
# 221              Vulpia_myurus    X               X          X
#
#      FORMA BIOLOGICA               DIMENSIONE FIORE  VISTOSITA'  \
# 0                1.0                            NaN           0
# 1                2.0             2,5 - 3 x 4- 5 cm            1
# 2                2.0                Capolini 5-7 mm           1
# 3                2.0                            NaN           0
# 4                1.0                            NaN           0
# ..               ...                            ...         ...
# 217              2.0                        5-6 mm            1
# 218              1.0                      1-1,5 mm            1
# 219              2.0                    1,5-2,5 mm            1
# 220              1.0   (30-40 mm Ø) fiori(20-25 mm)           0
# 221              1.0                    100-200 mm            0
#
#        PERIODO FIORITURA  DURATA      PRESENZA MERCATO  MERCATO AROMATICA  \
# 0          Maggio-giugno     NaN                   NaN      NaN         0
# 1       Maggio-settembre     NaN  Achillea millefolium      NaN         1
# 2          Giugno-agosto     NaN  Achillea millefolium      NaN         1
# 3          Giugno-agosto     NaN  Agrostis capillaris       NaN         0
# 4         Aprile-maggio      NaN                   NaN      NaN         0
# ..                   ...     ...                   ...      ...       ...
# 217         Maggio-agoso     NaN                   NaN      NaN         0
# 218  Febbraio-settembre      NaN         Viola cornuta      NaN         1
# 219        Aprile-luglio     NaN        Viola tricolor      NaN         1
# 220        Aprile-giugno     NaN        Vulpia ciliata      NaN         0
# 221        Aprile-giugno     NaN        Vulpia ciliata      NaN         0
#
#     IMPOLLINAZIONE  ALLERGENICITA’  TOSSICITA’
# 0                0               1           1
# 1                1               1           1
# 2                1               1           1
# 3                0               1           1
# 4                0               0           1
# ..             ...             ...         ...
# 217              1               1           0
# 218              1               1           1
# 219              1               1           1
# 220              0               1           1
# 221              0               1           1
#
# [222 rows x 15 columns]

# %% [markdown]
# ## Compute the Ornamental Score of the Plants

# %% [markdown]
# ### Test: Compute the Ornamental Value for a Single Plant

# %% [markdown]
# Note that the `get_score_sum` and `get_ornamental_index_value` functions are contained into the other file named `utilities.py`.

# %%
print('Score sum: ' + str(get_score_sum(raw_df.loc[0])))
print('Ornamental value: ' + str(get_ornamental_index_value(raw_df.loc[0])))
# Out:
# Score sum: 4.0
# Ornamental value: 1

# %% [markdown]
# ### Goal: Repeat the Previous Step for All the Plants

# %%
# Score sum
score_sum_series = raw_df.apply(get_score_sum, axis=1)
score_sum_series
# Out:
# 0       4.0
# 1      11.0
# 2      10.0
# 3       7.0
# 4       3.0
#        ...
# 217     7.0
# 218    10.0
# 219    10.0
# 220     6.0
# 221     6.0
# Length: 222, dtype: float64

# %%
# Ornamental value
ornamental_value_series = raw_df.apply(get_ornamental_index_value, axis=1)
ornamental_value_series
# Out:
# 0      1.0
# 1      3.0
# 2      3.0
# 3      2.0
# 4      1.0
#       ...
# 217    2.0
# 218    3.0
# 219    3.0
# 220    2.0
# 221    2.0
# Length: 222, dtype: float64

# %% [markdown]
# ## Generate the `json` Object

# %% [markdown]
# We want to add our figures of merit to each plant and then create a single `json` file containing all this information.

# %%
# Add the figures of merit to each plant
raw_df['SOMMA DEI PUNTEGGI'] = score_sum_series
raw_df['INDICE DI ORNAMENTALITA\''] = ornamental_value_series
raw_df
# Out:
#                          TAXON 4030 2330+6210(acid) 6210(calc)  \
# 0          Aegilops_geniculata  NaN             NaN          X
# 1         Achillea_millefolium    X               X        NaN
# 2           Achillea_tomentosa  NaN               X          X
# 3          Agrostis_capillaris    X               X        NaN
# 4            Aira_caryophyllea    X               X          X
# ..                         ...  ...             ...        ...
# 217  Vincetoxicum_hirundinaria    X             NaN        NaN
# 218             Viola_arvensis  NaN               X          X
# 219               Viola_canina    X             NaN        NaN
# 220             Vulpia_ciliata  NaN               X          X
# 221              Vulpia_myurus    X               X          X
#
#      FORMA BIOLOGICA               DIMENSIONE FIORE  VISTOSITA'  \
# 0                1.0                            NaN           0
# 1                2.0             2,5 - 3 x 4- 5 cm            1
# 2                2.0                Capolini 5-7 mm           1
# 3                2.0                            NaN           0
# 4                1.0                            NaN           0
# ..               ...                            ...         ...
# 217              2.0                        5-6 mm            1
# 218              1.0                      1-1,5 mm            1
# 219              2.0                    1,5-2,5 mm            1
# 220              1.0   (30-40 mm Ø) fiori(20-25 mm)           0
# 221              1.0                    100-200 mm            0
#
#        PERIODO FIORITURA  DURATA      PRESENZA MERCATO  MERCATO AROMATICA  \
# 0          Maggio-giugno     NaN                   NaN      NaN         0
# 1       Maggio-settembre     NaN  Achillea millefolium      NaN         1
# 2          Giugno-agosto     NaN  Achillea millefolium      NaN         1
# 3          Giugno-agosto     NaN  Agrostis capillaris       NaN         0
# 4         Aprile-maggio      NaN                   NaN      NaN         0
# ..                   ...     ...                   ...      ...       ...
# 217         Maggio-agoso     NaN                   NaN      NaN         0
# 218  Febbraio-settembre      NaN         Viola cornuta      NaN         1
# 219        Aprile-luglio     NaN        Viola tricolor      NaN         1
# 220        Aprile-giugno     NaN        Vulpia ciliata      NaN         0
# 221        Aprile-giugno     NaN        Vulpia ciliata      NaN         0
#
#     IMPOLLINAZIONE  ALLERGENICITA’  TOSSICITA’  SOMMA DEI PUNTEGGI  \
# 0                0               1           1                 4.0
# 1                1               1           1                11.0
# 2                1               1           1                10.0
# 3                0               1           1                 7.0
# 4                0               0           1                 3.0
# ..             ...             ...         ...                 ...
# 217              1               1           0                 7.0
# 218              1               1           1                10.0
# 219              1               1           1                10.0
# 220              0               1           1                 6.0
# 221              0               1           1                 6.0
#
#      INDICE DI ORNAMENTALITA'
# 0                         1.0
# 1                         3.0
# 2                         3.0
# 3                         2.0
# 4                         1.0
# ..                        ...
# 217                       2.0
# 218                       3.0
# 219                       3.0
# 220                       2.0
# 221                       2.0
#
# [222 rows x 17 columns]

# %% [markdown]
# Note that the `dataframe_to_json_array` function is contained into the other file named `utilities.py`.

# %%
# Convert the DataFrame to a json object
json_object = json.loads(raw_df.to_json(orient='records'))
json_object
# Out:
# [{'TAXON': 'Aegilops_geniculata',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 4.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Achillea_millefolium',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' 2,5 - 3 x 4- 5 cm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Achillea millefolium',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Achillea_tomentosa',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Capolini 5-7 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Achillea millefolium',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Agrostis_capillaris',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Agrostis capillaris ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Aira_caryophyllea',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-maggio ',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 3.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Ajuga_chamaepitys',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': 'Lunghezza 10-17 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Ajuga reptans',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.5,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Allium_sphaerocephalon',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '3.5-5.5 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Allium angolusum / cernuum ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Allium_vineale',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Allium fistolosum/ giganteum ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Alyssum_alyssoides',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Lunghezza 2-4 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Alyssum saxatile/ spinosum /montanum ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Anchusa_officinalis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Calice di 5-10 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Anchusa azurea ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Anisantha_sterilis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Anisantha_tectorum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Anthericum_liliago',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Lunghezza 16-22 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Anthericum liliago',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Anthoxanthum_odoratum',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'infiorescenza di 2-8 cm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Anthoxantum odoratum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Aphanes_arvensis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Calice di 1,8 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': '???',
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Arabidopsis_thaliana',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': '0,5 cm x 0,5 cm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Gen-apr    sett-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Arabis_glabra',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '6-9mm x 6-9mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Arabis caucasica ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Arenaria_serpyllifolia',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Calice 3 - 4 mm di Ø',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Arenaria serpylifolia ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Armeria_arenaria',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Armeria jumiperifolia ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Arrhenatherum_elatius',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'infiorescenza di 15-20 cm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Arrhenatherum bulbosum variegat.',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Artemisia_alba',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': '2-4 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Luglio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Artemisia annua ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Artemisia_campestris',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': '2-3 mm x 1,5- 3mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Agosto-ottobre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Artemisia drancunculus ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Artemisia_vulgaris',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Fiori 2-3 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Luglio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Artemisia absinthium',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Asperula_cynanchica',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Infiorescenza  Ø 2 - 15 (23) cm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Luglio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Asperula odorata ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Avena_barbata',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': ' 18-30 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Betonica_officinalis',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '10-15 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Betonica officinalis ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Bidens_frondosa',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': ' Ø2-4 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Luglio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Bidens aurea',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Biscutella_laevigata',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '4-8 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Blackstonia_perfoliata',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Bombycilaena_erecta',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': '1-1,2 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Botriochloa_ischaemum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '5-7 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-ottobre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Botriochla bladhii ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Bromopsis_erecta',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Spighette 15-25 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Bromus_hordeaceus',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Spighette  15-20 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Bromus inermis ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Bromus_squarrosus',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'spighette 3,5-5 (7) cm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Bromus inermis ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Bupleurum_baldense',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Buplerum fruticosum ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Calluna_vulgaris',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': '3-4 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'agosto-novembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Calluna vulgaris',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Cardus_nutans',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cardus_pycnocephalus',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': '17-15 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.5,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Carex_caryophyllea',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-maggio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'carex caryophyllea “Beatles',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Carex_contigua',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'carex caryophyllea “Beatles',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Carex_pallescens',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'carex caryophyllea “Beatles',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Carex_pilulifera',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'carex caryophyllea “Beatles',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Catapodium_rigidum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Centaurea_deusta',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' Ø10-20 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Centaurea cyanus',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Centaurea_stoebe',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' Ø150-250 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Centaurea cyanus',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Centaurium_erythraea',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Centaurium erythraea',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.5,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Centaurium_pulchellum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'maggio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Centaurium erythraea',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Cerastium_brachypetalum',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-maggio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'cerastium tomentosium',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cerastium_glomeratum',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'ogni mese dell’anno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'cerastium tomentosium',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cerastium_glutinosum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-maggio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'cerastium tomentosium',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cerastium_pumilum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-maggio ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'cerastium tomentosium',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cerastium_semidecandrum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-maggio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'cerastium tomentosium',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Chondrilla_juncea',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '10-13 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Chrysopogon gryllus ',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Spighette 7-9 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Cirsium_vulgare',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' 40-50 mm  ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Cirsium rivulare',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Clematis_vitalba',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': 'diametro 2,5 cm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Clematis armandii/montana',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Clinopodium_acinos',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Clinopodium vulgare',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Clinopodium_nepeta',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.5,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'maggio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Clinopodium nepeta ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.5,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Convolvolus_arvensis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Convolvolus cneorum/mauritanicus ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Corynephorus_canescens',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Corynephorus canescens ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Crepis_biennis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'capolini di 2-3 cm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-settembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': ' ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Crepis_vesicaria',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': ' 20 mm diametro',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Febbraio-ottobre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.5,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cruciata_pedemontana',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'diametro corolla 1 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': '???',
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Crupina_vulgaris',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 4.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Cuscuta_epithymum',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Cynodon_dactylon',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Cynodum dactylon',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Dactylis_glomerata',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Dactylis glomerata',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Danthonia_decumbens',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Daucus_carota',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': ' 50-70 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Daucus carota ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.5,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Dianthus_carthusianorum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '18-22 mm diametro',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Dianthus carthusianorum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Dianthus_seguieri',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Dianthus carthusianorum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Digitaria_sanguinalis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-novembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Diplotaxis_tenuifolia',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' 6(-8) x 10-12(-14) mm.',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-ottobre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Diplotaxis tenuifolia ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Echium_vulgare',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Echium russicum/amoenum red feathers ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Elytrigia_repens',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' spighette 5-7flore di 1-1,8 cm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Epilobium_dodonaei',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.5,
#   'DIMENSIONE FIORE': 'Diametro 20-30 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-settembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Epilobium angustifolium ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.5,
#   "INDICE DI ORNAMENTALITA'": None},
#  {'TAXON': 'Erigeron_canadensis',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': ' 3-4 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Erigeron aurantiacus/compositus discoideus/glaucus/ KARVINSKIANUS',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Erodium_cicutarium',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Marzo-novembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'E. trifolium/ E.reichardii/ manescavii',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Ervilia_hirsuta',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Corolla 4-5 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Eryngium_campestre',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Eryngium planum blue glitter/blue hobbit',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Erysimum_rhaeticum',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'ERYSIMUM BOWLES MAUVE/LINIFOLIUM VARIEGATUM/RED JEP',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Euphorbia_cyparissias',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'EUPHORBIA AMYGDALOIDES PURPUREA',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Euphorbia_falcata',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Marzo-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'EUPHORBIA CORALLOIDES',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Euphorbia_helioscopia',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'EUPHORBIA COROLLATA',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Euphorbia_maculata',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-ottobre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'EUPHORBIA DULCIS CHAMELEON',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Euphrasia_cisalpina',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Luglio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Festuca_stricta_ssp_trachyphylla',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Festuca mairei',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Festuca_filiformis',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Festuca punctoria /F. glauca',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Filago_arvensis',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'diametro 2-3 mm',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Filago_germanica',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Fumana_procumbens',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': 'petali 8-10 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Galium_divaricatum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Apile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Galium odoratum ',
#   'MERCATO': None,
#   'AROMATICA': '???',
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Galium_lucidum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'corolla di 3-5 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Galium odoratum ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Galium_parisiense',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': '???',
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Genista_germanica',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'G.hispanica/G.pilosa/G.germanica',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Genista_tinctoria',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': ' corolla lunga 12-15 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'G.tinctoria ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Geranium_colombinum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Petali 8-10 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Geranium sanguineum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Geranium_molle',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': 'Petali 5-6 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-settembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Geranium  CANTABRIGIENSE',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.5,
#   "INDICE DI ORNAMENTALITA'": None},
#  {'TAXON': 'Gladiolus_palustris',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '30-50 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'G.communis/G.italicus ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Globularia_bisnagarica',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Marzo-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'G.nudicaulis/cordifolia ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Gnaphalium_uliginosum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Giugno-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Gratiola_officinalis',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'G.officinalis',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Helianthemum_nummularium',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': 'petali piccoli 10-11 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'maggio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'H.nummularium/ golden queen/ fire dragon/the bride',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Herniaria_glabra',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'H.glabra ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Hippocrepis_comosa',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' 5-10 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-maggio ',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Hylotelephium_maximum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Fiori 5 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giungo-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'H.maximum ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Hypericum_perforatum',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Hypericum perforatum/polyphillum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Hypochoeris_glabra',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-maggio ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Hypochoeris radicata',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
# ...
#  {'TAXON': 'Senecio_vulgaris',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': ' 10 mm x 5 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Gennaio-dicembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Senecio rowleyanus/leucostachys ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Serratula_tinctoria',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '14-16 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Luglio-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Serratula tinctoria seoanei ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Sherardia_arvensis',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Silene_nutans',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': ' 18 mm X 12 mm',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agoso',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Silene acaulis ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Silene_otites',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Silene uniflora compacta ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Silene_vulgaris',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Silene vulgaris ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Sonchus_asper',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.5,
#   'DIMENSIONE FIORE': '30-40 mm di Ø',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Tutto l’anno ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Sonchus oleraceus',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.5,
#   "INDICE DI ORNAMENTALITA'": None},
#  {'TAXON': 'Stachys_recta',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': 'Corolla 1,5-2,2 cm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-Settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Stachys bizantina/lanata/grandiflora superba ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Teesdalia_nudicaulis',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Febbraio-maggio',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Teucrium_chamaedrys',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': 'Corolla 1,2-1,5 cm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Teucrium fruticans ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Teucrium_montanum',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': ' 8-10 mm di Ø',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agoso',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Teucrium chamaedrys',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Teucrium_scorodonia',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Teucrium hircanicum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Thymus_longicaulis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': 'Corolla 4-6 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Thymus serpyllum ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 12.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Thymus_pulegioides',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': 'Corolla 4-5 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Thymus pulegioides foxley',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 12.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Thymus_vulgaris',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 3.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Marzo-ottobre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Thymus vulgaris ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 12.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Trifolium_arvense',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Trifolium rubens ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Trifolium_campestre',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Fiore 4-6 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Trifolium repens ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Trifolium_nigrescens',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': '12-27 mm di Ø',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Marzo-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Trifolium repens ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Trifolium_repens',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.5,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-novembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Trifolium repens ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 11.5,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Trifolium_scabrum',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': 'Corolla di 4mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Trifolium repens ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Trigonella_officinalis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Trigonella foenum graecum',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Tuberaria_guttata',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Marzo-maggio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Tuberaria guttata ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Urtica_dioica',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-novembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'presente sul mercato come officinale',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 0,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Valerianella_locusta',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': '1,5- 2 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-maggio ',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Verbascum_lychnitis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-settembre',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Verbascum phoenicium/bombyciferum ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Verbascum_pulverulentum',
#   '4030': None,
#   '2330+6210(acid)': None,
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Giugno-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Verbascum nigrum',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Veronica officinalis',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.5,
#   'DIMENSIONE FIORE': ' 6-8 mm di Ø',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Maggio-agosto',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Veronica spicata ',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 9.5,
#   "INDICE DI ORNAMENTALITA'": None},
#  {'TAXON': 'Veronica_arvensis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Febbraio-settembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Veronica prostrata ',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Vicia_cracca',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '10-12 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agoso',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 8.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Vicia_lutea',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-maggio ',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 5.0,
#   "INDICE DI ORNAMENTALITA'": 1.0},
#  {'TAXON': 'Vicia_sativa',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': None,
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Marzo-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Vincetoxicum_hirundinaria',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '5-6 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Maggio-agoso',
#   'DURATA': None,
#   'PRESENZA MERCATO': None,
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 0,
#   'SOMMA DEI PUNTEGGI': 7.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Viola_arvensis',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': '1-1,5 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Febbraio-settembre ',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Viola cornuta',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Viola_canina',
#   '4030': 'X',
#   '2330+6210(acid)': None,
#   '6210(calc)': None,
#   'FORMA BIOLOGICA': 2.0,
#   'DIMENSIONE FIORE': '1,5-2,5 mm ',
#   "VISTOSITA'": 1,
#   'PERIODO FIORITURA': 'Aprile-luglio',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Viola tricolor',
#   'MERCATO': None,
#   'AROMATICA': 1,
#   'IMPOLLINAZIONE': 1,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 10.0,
#   "INDICE DI ORNAMENTALITA'": 3.0},
#  {'TAXON': 'Vulpia_ciliata',
#   '4030': None,
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': ' (30-40 mm Ø) fiori(20-25 mm)',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Vulpia ciliata',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0},
#  {'TAXON': 'Vulpia_myurus',
#   '4030': 'X',
#   '2330+6210(acid)': 'X',
#   '6210(calc)': 'X',
#   'FORMA BIOLOGICA': 1.0,
#   'DIMENSIONE FIORE': '100-200 mm ',
#   "VISTOSITA'": 0,
#   'PERIODO FIORITURA': 'Aprile-giugno',
#   'DURATA': None,
#   'PRESENZA MERCATO': 'Vulpia ciliata',
#   'MERCATO': None,
#   'AROMATICA': 0,
#   'IMPOLLINAZIONE': 0,
#   'ALLERGENICITA’': 1,
#   'TOSSICITA’': 1,
#   'SOMMA DEI PUNTEGGI': 6.0,
#   "INDICE DI ORNAMENTALITA'": 2.0}]

# %% [markdown]
# ## Store the `json` Object

# %% [markdown]
# ### Locally

# %% [markdown]
# Note that the `store_locally` function is contained into the other file named `utilities.py`.
#
# The file will be saved in the root of this repository.

# %%
store_locally(json_object)

# %% [markdown]
# ### Into Our MongoDB Istance

# %% [markdown]
# Note that the `store_into_mongodb_istance` function is contained into the other file named `utilities.py`.

# %%
store_into_mongodb_istance(json_object)

# %% [markdown]
# ## Test: Load a Single Document (Plant) From the MongoDB Instance

# %%
client = pymongo.MongoClient(get_connection_string())

# Test: show the first record
client.OVE.data.find()[0]
# Out:
# {'_id': ObjectId('622375de530de6ccfba98f9d'),
#  'TAXON': 'Aegilops_geniculata',
#  '4030': None,
#  '2330+6210(acid)': None,
#  '6210(calc)': 'X',
#  'FORMA BIOLOGICA': 1.0,
#  'DIMENSIONE FIORE': None,
#  "VISTOSITA'": 0,
#  'PERIODO FIORITURA': 'Maggio-giugno',
#  'DURATA': None,
#  'PRESENZA MERCATO': None,
#  'MERCATO': None,
#  'AROMATICA': 0,
#  'IMPOLLINAZIONE': 0,
#  'ALLERGENICITA’': 1,
#  'TOSSICITA’': 1,
#  'SOMMA DEI PUNTEGGI': 4.0,
#  "INDICE DI ORNAMENTALITA'": 1.0}
